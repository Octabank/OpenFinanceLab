# %%
import numpy as np
import pandas as pd
import json
import csv
import requests
import time
import os
import shutil
import matplotlib.pyplot as plt
from markowitz import *

# %%
pd.set_option('display.max_rows',10)

# %% [markdown]
# - Primeiro coletamos os dados do mercado em um dict:

# %%
market = coimetrics_get_whole_market()

# %% [markdown]
# - depois montamos um dataframe contendo apenas moedas existentes desde a data estabelecida

# %%
mkt = merge_market_data(market, pd.Timestamp(2018,1,1))

# %% [markdown]
# - Em seguida definimos nosso portfolio com as moedas em que estamos interessados

# %%
l = ['btc','ltc','eth','ada']
#todas as opções de moedas podem ser obtidas em get_assets_from_coimetrics()
portfolio = get_portfolio_data_from_market_dataframe(mkt, l)

# %% [markdown]
# - Em seguida simulamos alguns portfolios, e definimos o com melhor sharpe(em vermelho) e o mais seguro(em preto)

# %%
a = markovitz_monte_carlo(portfolio)
print('sharpe',a[3])
# Out:
# sharpe 3.582110750936836
